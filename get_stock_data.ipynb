# %% [markdown]
# <a href="https://colab.research.google.com/github/wbfrench1/stock/blob/main/get_stock_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/wbfrench1/stock/blob/main/src/get_stock_data.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import pandas as pd
import numpy as np
import yfinance as yf
#from yahoofinance import HistoricalPrices
import json
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime
from datetime import timezone

# %% [markdown]
# # Plan
#
# 1. Graph Historical Performance
#    1. Pull one stocks data
#    1. Get stock data over a time period
#    1. Graph stock price over time period
# 1. Get S&P500 company info
# 1. Get multiple ticker price data
# 1. Get recent adjusted closing price
# 1.

# %% [markdown]
# # 1. Graph Historical Performance

# %% [markdown]
# ### 1. Pull one stocks data

# %%
meta = yf.Ticker("META")
str_period = '5y'
str_interval = '1mo'

# %% [markdown]
# ### Get Data over a specified period of time and interval

# %%
meta.history(period=str_period,
             interval=str_interval).head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-06-01 00:00:00-04:00  223.536475  244.039849  206.138475  226.004852
# 2020-07-01 00:00:00-04:00  227.428115  254.649823  225.835614  252.480042
# 2020-08-01 00:00:00-04:00  251.464817  303.240811  246.269302  291.824615
# 2020-09-01 00:00:00-04:00  293.327537  302.175849  242.984816  260.671448
# 2020-10-01 00:00:00-04:00  264.105276  283.901958  253.624672  261.875763
#
#                               Volume  Dividends  Stock Splits
# Date
# 2020-06-01 00:00:00-04:00  548043800        0.0           0.0
# 2020-07-01 00:00:00-04:00  517599700        0.0           0.0
# 2020-08-01 00:00:00-04:00  574239100        0.0           0.0
# 2020-09-01 00:00:00-04:00  499115300        0.0           0.0
# 2020-10-01 00:00:00-04:00  454101600        0.0           0.0

# %% [markdown]
# ### Graph stock data over time period

# %%
t_figsize = (12,5)
fig, ax = plt.subplots(figsize=t_figsize)
plt.xticks(rotation=45)
sns.lineplot(x= meta.history(period=str_period,
                             interval=str_interval).index,
             y= meta.history(period=str_period,
                             interval=str_interval)['Close'],
             ax= ax)
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
meta.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-04-14 00:00:00-04:00  556.169983  557.770020  528.280029  531.479980
# 2025-04-15 00:00:00-04:00  532.109985  537.940002  517.500000  521.520020
# 2025-04-16 00:00:00-04:00  508.510010  513.369995  495.630005  502.309998
# 2025-04-17 00:00:00-04:00  505.250000  507.299988  498.010010  501.480011
# 2025-04-21 00:00:00-04:00  491.329987  493.500000  479.799988  484.660004
# 2025-04-22 00:00:00-04:00  491.869995  506.880005  486.359985  500.279999
# 2025-04-23 00:00:00-04:00  528.530029  535.340027  516.520020  520.270020
# 2025-04-24 00:00:00-04:00  518.729980  533.900024  517.500000  533.150024
# 2025-04-25 00:00:00-04:00  546.799988  549.859985  536.250000  547.270020
# 2025-04-28 00:00:00-04:00  555.640015  558.489990  540.590027  549.739990
# 2025-04-29 00:00:00-04:00  546.000000  556.570007  544.119995  554.440002
# 2025-04-30 00:00:00-04:00  538.400024  549.099976  529.500000  549.000000
# 2025-05-01 00:00:00-04:00  592.080017  592.950012  570.500000  572.210022
# 2025-05-02 00:00:00-04:00  583.460022  604.340027  578.330017  597.020020
# 2025-05-05 00:00:00-04:00  591.219971  603.210022  588.049988  599.270020
# 2025-05-06 00:00:00-04:00  592.530029  596.030029  586.580017  587.309998
# 2025-05-07 00:00:00-04:00  590.359985  603.080017  586.669983  596.809998
# 2025-05-08 00:00:00-04:00  606.289978  611.299988  596.619995  598.010010
# 2025-05-09 00:00:00-04:00  603.719971  606.969971  591.710022  592.489990
# 2025-05-12 00:00:00-04:00  630.919983  640.390015  621.030029  639.429993
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-04-14 00:00:00-04:00  14130900        0.0           0.0
# 2025-04-15 00:00:00-04:00  15558700        0.0           0.0
# 2025-04-16 00:00:00-04:00  18735100        0.0           0.0
# 2025-04-17 00:00:00-04:00  14593500        0.0           0.0
# 2025-04-21 00:00:00-04:00  16166000        0.0           0.0
# 2025-04-22 00:00:00-04:00  17399400        0.0           0.0
# 2025-04-23 00:00:00-04:00  18173900        0.0           0.0
# 2025-04-24 00:00:00-04:00  13910000        0.0           0.0
# 2025-04-25 00:00:00-04:00  17098900        0.0           0.0
# 2025-04-28 00:00:00-04:00  15179000        0.0           0.0
# 2025-04-29 00:00:00-04:00  11835000        0.0           0.0
# 2025-04-30 00:00:00-04:00  29244000        0.0           0.0
# 2025-05-01 00:00:00-04:00  31159000        0.0           0.0
# 2025-05-02 00:00:00-04:00  24739300        0.0           0.0
# 2025-05-05 00:00:00-04:00  13887700        0.0           0.0
# 2025-05-06 00:00:00-04:00  10600700        0.0           0.0
# 2025-05-07 00:00:00-04:00  13139100        0.0           0.0
# 2025-05-08 00:00:00-04:00  14622800        0.0           0.0
# 2025-05-09 00:00:00-04:00  10427300        0.0           0.0
# 2025-05-12 00:00:00-04:00  21925900        0.0           0.0

# %% [markdown]
# # Get S&P 500 stock tickers

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df_sp500_co_info = table[0]
df_sp500_co_info.head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
df_sp500_co_info['Symbol']
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 499     XYL
# 500     YUM
# 501    ZBRA
# 502     ZBH
# 503     ZTS
# Name: Symbol, Length: 504, dtype: object

# %% [markdown]
# https://www.marketdata.app/how-to-use-the-yahoo-finance-api/

# %% [markdown]
# # Get Multiple Ticker Price Data

# %% [markdown]
# ## Put S&P 500 tickers into a string

# %%
# If the below download fails, then it might be because of the replacement of . with -
str_sp500_stk_tkrs= ' '.join(i if '.' not in i else i.replace('.','-') for i in df_sp500_co_info['Symbol'])
print('Number of tickers in sp500:', len(df_sp500_co_info['Symbol']), '\n')
str_sp500_stk_tkrs
# Out:
# Number of tickers in sp500: 504
# 'MMM AOS ABT ABBV ACN ADBE AMD AES AFL A APD ABNB AKAM ALB ARE ALGN ALLE LNT ALL GOOGL GOOG MO AMZN AMCR AEE AEP AXP AIG AMT AWK AMP AME AMGN APH ADI ANSS AON APA APO AAPL AMAT APTV ACGL ADM ANET AJG AIZ T ATO ADSK ADP AZO AVB AVY AXON BKR BALL BAC BAX BDX BRK-B BBY TECH BIIB BLK BX BK BA BKNG BSX BMY AVGO BR BRO BF-B BLDR BG BXP COIN CHRW CDNS CZR CPT CPB COF CAH KMX CCL CARR CAT CBOE CBRE CDW COR CNC CNP CF CRL SCHW CHTR CVX CMG CB CHD CI CINF CTAS CSCO C CFG CLX CME CMS KO CTSH CL CMCSA CAG COP ED STZ CEG COO CPRT GLW CPAY CTVA CSGP COST CTRA CRWD CCI CSX CMI CVS DHR DRI DVA DAY DECK DE DELL DAL DVN DXCM FANG DLR DFS DG DLTR D DPZ DASH DOV DOW DHI DTE DUK DD EMN ETN EBAY ECL EIX EW EA ELV EMR ENPH ETR EOG EPAM EQT EFX EQIX EQR ERIE ESS EL EG EVRG ES EXC EXE EXPE EXPD EXR XOM FFIV FDS FICO FAST FRT FDX FIS FITB FSLR FE FI F FTNT FTV FOXA FOX BEN FCX GRMN IT GE GEHC GEV GEN GNRC GD GIS GM GPC GILD GPN GL GDDY GS HAL HIG HAS HCA DOC HSIC HSY HES HPE HLT HOLX HD HON HRL HST HWM HPQ HUBB HUM HBAN HII IBM IEX IDXX ITW INCY IR PODD INTC ICE IFF IP IPG INTU ISRG IVZ INVH IQV IRM JBHT JBL JKHY J JNJ JCI JPM JNPR K KVUE KDP KEY KEYS KMB KIM KMI KKR KLAC KHC KR LHX LH LRCX LW LVS LDOS LEN LII LLY LIN LYV LKQ LMT L LOW LULU LYB MTB MPC MKTX MAR MMC MLM MAS MA MTCH MKC MCD MCK MDT MRK META MET MTD MGM MCHP MU MSFT MAA MRNA MHK MOH TAP MDLZ MPWR MNST MCO MS MOS MSI MSCI NDAQ NTAP NFLX NEM NWSA NWS NEE NKE NI NDSN NSC NTRS NOC NCLH NRG NUE NVDA NVR NXPI ORLY OXY ODFL OMC ON OKE ORCL OTIS PCAR PKG PLTR PANW PARA PH PAYX PAYC PYPL PNR PEP PFE PCG PM PSX PNW PNC POOL PPG PPL PFG PG PGR PLD PRU PEG PTC PSA PHM PWR QCOM DGX RL RJF RTX O REG REGN RF RSG RMD RVTY ROK ROL ROP ROST RCL SPGI CRM SBAC SLB STX SRE NOW SHW SPG SWKS SJM SW SNA SOLV SO LUV SWK SBUX STT STLD STE SYK SMCI SYF SNPS SYY TMUS TROW TTWO TPR TRGP TGT TEL TDY TER TSLA TXN TPL TXT TMO TJX TKO TSCO TT TDG TRV TRMB TFC TYL TSN USB UBER UDR ULTA UNP UAL UPS URI UNH UHS VLO VTR VLTO VRSN VRSK VZ VRTX VTRS VICI V VST VMC WRB GWW WAB WBA WMT DIS WBD WM WAT WEC WFC WELL WST WDC WY WSM WMB WTW WDAY WYNN XEL XYL YUM ZBRA ZBH ZTS'

# %% [markdown]
# ## Query Multiple Tickers on yahoo finance

# %%
str_today = datetime.today().strftime("%Y-%m-%d")

# %%
data = yf.download(str_sp500_stk_tkrs, start="2018-01-01", end=str_today)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  504 of 504 completed

# %%
print('data.shape:', data.shape)
data.tail(5)
# Out:
# data.shape: (1850, 2520)
# Price            Close                                                  \
# Ticker               A        AAPL        ABBV        ABNB         ABT
# Date
# 2025-05-06  105.239998  198.250015  187.149994  121.669998  133.059998
# 2025-05-07  107.519997  195.992981  188.089996  123.120003  133.949997
# 2025-05-08  108.699997  197.231369  185.580002  126.389999  134.000000
# 2025-05-09  106.930000  198.270004  184.600006  127.040001  133.240005
# 2025-05-12  115.550003  210.789993  190.070007  134.210007  131.990005
#
# Price                                                                 ...  \
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...
# Date                                                                  ...
# 2025-05-06  93.000000  303.799988  382.980011  195.600006  48.320000  ...
# 2025-05-07  92.690002  306.089996  384.970001  199.860001  47.880001  ...
# 2025-05-08  94.559998  308.880005  383.989990  202.779999  47.700001  ...
# 2025-05-09  94.540001  307.899994  383.279999  207.509995  48.529999  ...
# 2025-05-12  94.629997  322.089996  395.940002  223.149994  49.900002  ...
#
# Price       Volume                                                         \
# Ticker         WTW       WY     WYNN      XEL       XOM      XYL      YUM
# Date
# 2025-05-06  728600  5555900  3011500  2765400  16303400  1606800  2097000
# 2025-05-07  816100  4117600  3846700  4552300  12332200  1664200  1416000
# 2025-05-08  706800  3812400  3041300  3160000  19196500   986100  1410900
# 2025-05-09  396300  4948200  3216400  2479300  10992100   664800  1068500
# 2025-05-12  487800  3661700  4636800  4782500  14241700  1531600  1552700
#
# Price
# Ticker          ZBH     ZBRA      ZTS
# Date
# 2025-05-06  4203100   521600  4124400
# 2025-05-07  2662400   822600  4453800
# 2025-05-08  2886100   711000  5580100
# 2025-05-09  3438600   700800  4243100
# 2025-05-12  3166300  1726700  3453700
#
# [5 rows x 2520 columns]

# %%
# convert the index to datetime
data.index = pd.to_datetime(data.index, unit='ns')
data.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2025-04-29', '2025-04-30', '2025-05-01', '2025-05-02',
#                '2025-05-05', '2025-05-06', '2025-05-07', '2025-05-08',
#                '2025-05-09', '2025-05-12'],
#               dtype='datetime64[ns]', name='Date', length=1850, freq=None)

# %%
#This adds the UTC timezone to the today value
datetime.now(timezone.utc)
# Out:
# datetime.datetime(2025, 5, 13, 12, 20, 22, 199777, tzinfo=datetime.timezone.utc)

# %%
#Get today's Date - time stamp closest day
# Assuming 'data' is your DataFrame
if data.index.tz is None:
    data.index = data.index.tz_localize('UTC')

ts_clst_day = data.index[data.index.get_indexer([datetime.now(timezone.utc)], method='nearest')]
ts_clst_day
# Out:
# DatetimeIndex(['2025-05-12 00:00:00+00:00'], dtype='datetime64[ns, UTC]', name='Date', freq=None)

# %% [markdown]
# # Create Min/Max Current DataFrame

# %% [markdown]
# ## Get Adjusted Closing Price

# %%
# gets most recent stock price close for each S&P 500 stock
# transforms from a row into a column
df_cur_stkpr1 = data.loc[ts_clst_day, 'Close'].stack().loc[ts_clst_day,:].copy()
df_cur_stkpr1
# Out:
# Date                       Ticker
# 2025-05-12 00:00:00+00:00  A         115.550003
#                            AAPL      210.789993
#                            ABBV      190.070007
#                            ABNB      134.210007
#                            ABT       131.990005
#                                         ...
#                            XYL       127.250000
#                            YUM       146.800003
#                            ZBH        98.220001
#                            ZBRA      300.109985
#                            ZTS       161.919998
# Length: 504, dtype: float64

# %%
# create a dataframe of current stock prices with stock tickers as the index
df_cur_stkpr1 = df_cur_stkpr1.loc[ts_clst_day].reset_index().drop(columns='Date').set_index('Ticker')
df_cur_stkpr1
#df_cur_stkpr.loc['2023-07-07']
#ts_clst_day[0].strftime('YYYY-MM-DD')
# Out:
#                  0
# Ticker
# A       115.550003
# AAPL    210.789993
# ABBV    190.070007
# ABNB    134.210007
# ABT     131.990005
# ...            ...
# XYL     127.250000
# YUM     146.800003
# ZBH      98.220001
# ZBRA    300.109985
# ZTS     161.919998
#
# [504 rows x 1 columns]

# %%
df_cur_stkpr1 = pd.DataFrame(df_cur_stkpr1).rename(columns={0:'Cur_StkPr'})
df_cur_stkpr1
# Out:
#          Cur_StkPr
# Ticker
# A       115.550003
# AAPL    210.789993
# ABBV    190.070007
# ABNB    134.210007
# ABT     131.990005
# ...            ...
# XYL     127.250000
# YUM     146.800003
# ZBH      98.220001
# ZBRA    300.109985
# ZTS     161.919998
#
# [504 rows x 1 columns]

# %% [markdown]
# ## Transform dataframe

# %%
# more the date into the columns
df = data.copy()
df.reset_index(inplace=True)
df.head()
# Out:
# Price                       Date      Close                             \
# Ticker                                    A       AAPL       ABBV ABNB
# 0      2018-01-02 00:00:00+00:00  64.044174  40.426823  71.013649  NaN
# 1      2018-01-03 00:00:00+00:00  65.673698  40.419788  72.124931  NaN
# 2      2018-01-04 00:00:00+00:00  65.181068  40.607533  71.713615  NaN
# 3      2018-01-05 00:00:00+00:00  66.223198  41.069870  72.961998  NaN
# 4      2018-01-08 00:00:00+00:00  66.365311  40.917309  71.792984  NaN
#
# Price                                                            ...  Volume  \
# Ticker        ABT       ACGL         ACN        ADBE        ADI  ...     WTW
# 0       51.537838  27.988113  137.391541  177.699997  78.786240  ...  817700
# 1       51.651791  28.013470  138.025635  181.039993  79.763649  ...  771200
# 2       51.564129  28.118069  139.659988  183.220001  79.676407  ...  800900
# 3       51.713165  28.007132  140.812027  185.339996  79.999283  ...  646700
# 4       51.564129  28.010302  141.937317  185.039993  80.138908  ...  632700
#
# Price                                                                          \
# Ticker       WY     WYNN      XEL       XOM     XYL      YUM      ZBH    ZBRA
# 0       3144000  2581200  2443400  11469300  877800  1747800  1818259  310600
# 1       2922800  3530900  4114900  13957700  778800  2554900  1368664  253000
# 2       2727800  2708800  2807000  10863000  796500  1971200  1105396  435200
# 3       2924800  2186600  3728000  11047600  666800  1927100  1095302  301800
# 4       2760800  1803800  3837600  10927100  554700  1599400  1286985  218600
#
# Price
# Ticker      ZTS
# 0       2135600
# 1       2328200
# 2       2534000
# 3       2166100
# 4       3631400
#
# [5 rows x 2521 columns]

# %% [markdown]
# ### Convert multi-col index to single-col index

# %%
df1 = df.copy()
df1.columns = [' '.join((col[0].replace(' ',''),col[1])).strip() for col in df1.columns.values]
df1.head(1)
# Out:
#                        Date    Close A  Close AAPL  Close ABBV  Close ABNB  \
# 0 2018-01-02 00:00:00+00:00  64.044174   40.426823   71.013649         NaN
#
#    Close ABT  Close ACGL   Close ACN  Close ADBE  Close ADI  ...  Volume WTW  \
# 0  51.537838   27.988113  137.391541  177.699997   78.78624  ...      817700
#
#    Volume WY  Volume WYNN  Volume XEL  Volume XOM  Volume XYL  Volume YUM  \
# 0    3144000      2581200     2443400    11469300      877800     1747800
#
#    Volume ZBH  Volume ZBRA  Volume ZTS
# 0     1818259       310600     2135600
#
# [1 rows x 2521 columns]

# %% [markdown]
# ### Convert multiple close-type/stock to 2 cols

# %%
df2 = df1.melt(id_vars=['Date'], value_vars=df1.columns[1:],).copy()

# %%
df2['Value_Type'] =  df2['variable'].str.split(' ').str[0]
df2['Stock_Tkr'] =  df2['variable'].str.split(' ').str[1]
df2.drop(columns=['variable'], inplace=True)
df2 = df2[['Date', 'Value_Type', 'Stock_Tkr', 'value']].copy()
df2.head()
# Out:
#                        Date Value_Type Stock_Tkr      value
# 0 2018-01-02 00:00:00+00:00      Close         A  64.044174
# 1 2018-01-03 00:00:00+00:00      Close         A  65.673698
# 2 2018-01-04 00:00:00+00:00      Close         A  65.181068
# 3 2018-01-05 00:00:00+00:00      Close         A  66.223198
# 4 2018-01-08 00:00:00+00:00      Close         A  66.365311

# %%
# demo conversion of tidy data to user friendly format
df2.loc[df2['Value_Type'] == 'AdjClose'].pivot_table(index='Date',
                                                     columns='Stock_Tkr',
                                                     values='value',
                                                     aggfunc=np.sum)
# Out:
# <ipython-input-25-4b67e6d6ae40>:2: FutureWarning: The provided callable <function sum at 0x7e79f6a08cc0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df2.loc[df2['Value_Type'] == 'AdjClose'].pivot_table(index='Date',
# Empty DataFrame
# Columns: []
# Index: []

# %%
# review old data format
df.head(1)
# Out:
# Price                       Date      Close                             \
# Ticker                                    A       AAPL       ABBV ABNB
# 0      2018-01-02 00:00:00+00:00  64.044174  40.426823  71.013649  NaN
#
# Price                                                           ...  Volume  \
# Ticker        ABT       ACGL         ACN        ADBE       ADI  ...     WTW
# 0       51.537838  27.988113  137.391541  177.699997  78.78624  ...  817700
#
# Price                                                                          \
# Ticker       WY     WYNN      XEL       XOM     XYL      YUM      ZBH    ZBRA
# 0       3144000  2581200  2443400  11469300  877800  1747800  1818259  310600
#
# Price
# Ticker      ZTS
# 0       2135600
#
# [1 rows x 2521 columns]

# %%
df.loc[df['Date'] == '2020-05-15']
# Out:
# Price                       Date      Close                             \
# Ticker                                    A       AAPL       ABBV ABNB
# 596    2020-05-15 00:00:00+00:00  78.880943  74.778847  73.909966  NaN
#
# Price                                                            ...   Volume  \
# Ticker        ABT       ACGL         ACN        ADBE        ADI  ...      WTW
# 596     82.267975  21.851648  170.713287  365.299988  93.009056  ...  1363900
#
# Price                                                                         \
# Ticker       WY     WYNN      XEL       XOM     XYL      YUM     ZBH    ZBRA
# 596     5329100  3885000  5744300  22445600  985200  3998200  881371  383100
#
# Price
# Ticker      ZTS
# 596     2921700
#
# [1 rows x 2521 columns]

# %% [markdown]
# ## Create the Min/Max Dataframe

# %%
# Find min/max value index to facilitate getting the date of the min/max
pd.DataFrame(list(data.index[data.reset_index()[['Close']].idxmin().values]),
             columns=['5Yr_StkPr_Low_Date'], index=data['Close'].columns)
# Out:
#               5Yr_StkPr_Low_Date
# Ticker
# A      2018-06-27 00:00:00+00:00
# AAPL   2019-01-03 00:00:00+00:00
# ABBV   2019-08-15 00:00:00+00:00
# ABNB   2022-12-28 00:00:00+00:00
# ABT    2018-02-08 00:00:00+00:00
# ...                          ...
# XYL    2020-03-23 00:00:00+00:00
# YUM    2020-03-23 00:00:00+00:00
# ZBH    2020-03-18 00:00:00+00:00
# ZBRA   2018-01-02 00:00:00+00:00
# ZTS    2018-02-08 00:00:00+00:00
#
# [504 rows x 1 columns]

# %%
# Show period low, high, current
df_min_max = pd.concat([pd.DataFrame(list(data.index[data.reset_index()[['Close']].idxmin().values]),
             columns=['5Yr_StkPr_Low_Date'], index=data['Close'].columns),
                        pd.DataFrame(data['Close'].min(),
                        columns=['5Yr_StkPr_Low']
                        ),
                        pd.DataFrame(list(data.index[data.reset_index()[['Close']].idxmax().values]),
                                     columns=['5Yr_StkPr_High_Date'],
                                     index=data['Close'].columns),
                        pd.DataFrame(data['Close'].max(),
                                     columns=['5Yr_StkPr_High']),
                        pd.DataFrame(df_cur_stkpr1).rename(columns={0:'Cur_StkPr'})], axis=1)
df_min_max.head()
# Out:
#               5Yr_StkPr_Low_Date  5Yr_StkPr_Low       5Yr_StkPr_High_Date  \
# Ticker
# A      2018-06-27 00:00:00+00:00      58.053265 2021-09-03 00:00:00+00:00
# AAPL   2019-01-03 00:00:00+00:00      33.870842 2024-12-26 00:00:00+00:00
# ABBV   2019-08-15 00:00:00+00:00      49.170662 2025-03-10 00:00:00+00:00
# ABNB   2022-12-28 00:00:00+00:00      82.489998 2021-02-11 00:00:00+00:00
# ABT    2018-02-08 00:00:00+00:00      49.564602 2025-03-03 00:00:00+00:00
#
#         5Yr_StkPr_High   Cur_StkPr
# Ticker
# A           174.784485  115.550003
# AAPL        258.396667  210.789993
# ABBV        214.676071  190.070007
# ABNB        216.839996  134.210007
# ABT         139.573471  131.990005

# %% [markdown]
# ## Add Company Names

# %%
df_min_max_cur= df_min_max.merge(df_sp500_co_info[['Symbol',
                                               'Security']],
                             how='left', left_index= True,
                             right_on='Symbol').copy()
df_min_max_cur.head()
# Out:
#             5Yr_StkPr_Low_Date  5Yr_StkPr_Low       5Yr_StkPr_High_Date  \
# 9.0  2018-06-27 00:00:00+00:00      58.053265 2021-09-03 00:00:00+00:00
# 39.0 2019-01-03 00:00:00+00:00      33.870842 2024-12-26 00:00:00+00:00
# 3.0  2019-08-15 00:00:00+00:00      49.170662 2025-03-10 00:00:00+00:00
# 11.0 2022-12-28 00:00:00+00:00      82.489998 2021-02-11 00:00:00+00:00
# 2.0  2018-02-08 00:00:00+00:00      49.564602 2025-03-03 00:00:00+00:00
#
#       5Yr_StkPr_High   Cur_StkPr Symbol              Security
# 9.0       174.784485  115.550003      A  Agilent Technologies
# 39.0      258.396667  210.789993   AAPL            Apple Inc.
# 3.0       214.676071  190.070007   ABBV                AbbVie
# 11.0      216.839996  134.210007   ABNB                Airbnb
# 2.0       139.573471  131.990005    ABT   Abbott Laboratories

# %%
df_min_max_cur = df_min_max_cur.reset_index().drop(columns='index').copy()
df_min_max_cur
# Out:
#            5Yr_StkPr_Low_Date  5Yr_StkPr_Low       5Yr_StkPr_High_Date  \
# 0   2018-06-27 00:00:00+00:00      58.053265 2021-09-03 00:00:00+00:00
# 1   2019-01-03 00:00:00+00:00      33.870842 2024-12-26 00:00:00+00:00
# 2   2019-08-15 00:00:00+00:00      49.170662 2025-03-10 00:00:00+00:00
# 3   2022-12-28 00:00:00+00:00      82.489998 2021-02-11 00:00:00+00:00
# 4   2018-02-08 00:00:00+00:00      49.564602 2025-03-03 00:00:00+00:00
# ..                        ...            ...                       ...
# 499 2020-03-23 00:00:00+00:00      53.369892 2024-05-21 00:00:00+00:00
# 500 2020-03-23 00:00:00+00:00      51.484676 2025-03-07 00:00:00+00:00
# 501 2020-03-18 00:00:00+00:00      75.125786 2021-04-29 00:00:00+00:00
# 502 2018-01-02 00:00:00+00:00     103.709999 2021-12-10 00:00:00+00:00
# 503 2018-02-08 00:00:00+00:00      67.717407 2021-12-29 00:00:00+00:00
#
#      5Yr_StkPr_High   Cur_StkPr Symbol              Security
# 0        174.784485  115.550003      A  Agilent Technologies
# 1        258.396667  210.789993   AAPL            Apple Inc.
# 2        214.676071  190.070007   ABBV                AbbVie
# 3        216.839996  134.210007   ABNB                Airbnb
# 4        139.573471  131.990005    ABT   Abbott Laboratories
# ..              ...         ...    ...                   ...
# 499      144.330322  127.250000    XYL            Xylem Inc.
# 500      162.529999  146.800003    YUM           Yum! Brands
# 501      167.999115   98.220001    ZBH         Zimmer Biomet
# 502      614.549988  300.109985   ZBRA    Zebra Technologies
# 503      239.098679  161.919998    ZTS                Zoetis
#
# [504 rows x 7 columns]

# %%
df_min_max_cur= df_min_max_cur[['Symbol', 'Security', '5Yr_StkPr_Low_Date',
                                '5Yr_StkPr_Low', '5Yr_StkPr_High_Date',
                                '5Yr_StkPr_High', 'Cur_StkPr']].copy()

# %% [markdown]
# # Find % Decline from High

# %%
df_min_max_cur['Pct_Chg_f_High'] = ((df_min_max_cur['Cur_StkPr']
                                    - df_min_max_cur['5Yr_StkPr_High']
                                    )
                                     /df_min_max_cur['5Yr_StkPr_High']
                                    )
df_min_max_cur
# Out:
#     Symbol              Security        5Yr_StkPr_Low_Date  5Yr_StkPr_Low  \
# 0        A  Agilent Technologies 2018-06-27 00:00:00+00:00      58.053265
# 1     AAPL            Apple Inc. 2019-01-03 00:00:00+00:00      33.870842
# 2     ABBV                AbbVie 2019-08-15 00:00:00+00:00      49.170662
# 3     ABNB                Airbnb 2022-12-28 00:00:00+00:00      82.489998
# 4      ABT   Abbott Laboratories 2018-02-08 00:00:00+00:00      49.564602
# ..     ...                   ...                       ...            ...
# 499    XYL            Xylem Inc. 2020-03-23 00:00:00+00:00      53.369892
# 500    YUM           Yum! Brands 2020-03-23 00:00:00+00:00      51.484676
# 501    ZBH         Zimmer Biomet 2020-03-18 00:00:00+00:00      75.125786
# 502   ZBRA    Zebra Technologies 2018-01-02 00:00:00+00:00     103.709999
# 503    ZTS                Zoetis 2018-02-08 00:00:00+00:00      67.717407
#
#           5Yr_StkPr_High_Date  5Yr_StkPr_High   Cur_StkPr  Pct_Chg_f_High
# 0   2021-09-03 00:00:00+00:00      174.784485  115.550003       -0.338900
# 1   2024-12-26 00:00:00+00:00      258.396667  210.789993       -0.184239
# 2   2025-03-10 00:00:00+00:00      214.676071  190.070007       -0.114619
# 3   2021-02-11 00:00:00+00:00      216.839996  134.210007       -0.381064
# 4   2025-03-03 00:00:00+00:00      139.573471  131.990005       -0.054333
# ..                        ...             ...         ...             ...
# 499 2024-05-21 00:00:00+00:00      144.330322  127.250000       -0.118342
# 500 2025-03-07 00:00:00+00:00      162.529999  146.800003       -0.096782
# 501 2021-04-29 00:00:00+00:00      167.999115   98.220001       -0.415354
# 502 2021-12-10 00:00:00+00:00      614.549988  300.109985       -0.511659
# 503 2021-12-29 00:00:00+00:00      239.098679  161.919998       -0.322790
#
# [504 rows x 8 columns]

# %%
threshold = -.5

# %%
# try to add the dates that the low and high prices were reached
print(df_min_max_cur.loc[(df_min_max_cur['Pct_Chg_f_High'] < threshold)].shape, '\n')
df_min_max_cur.loc[(df_min_max_cur['Pct_Chg_f_High'] < threshold)].sort_values(by='Pct_Chg_f_High')
# Out:
# (55, 8)
#     Symbol                         Security        5Yr_StkPr_Low_Date  \
# 321   MRNA                          Moderna 2019-08-05 00:00:00+00:00
# 482    WBD           Warner Bros. Discovery 2024-08-12 00:00:00+00:00
# 360   PARA                 Paramount Global 2024-06-18 00:00:00+00:00
# 161   ENPH                   Enphase Energy 2018-01-18 00:00:00+00:00
# 327   MTCH                      Match Group 2025-04-08 00:00:00+00:00
# 481    WBA         Walgreens Boots Alliance 2024-09-25 00:00:00+00:00
# 157     EL     Estée Lauder Companies (The) 2025-04-08 00:00:00+00:00
# 20     ALB            Albemarle Corporation 2020-03-23 00:00:00+00:00
# 477   VTRS                          Viatris 2025-04-10 00:00:00+00:00
# 389   PYPL                           PayPal 2023-10-27 00:00:00+00:00
# 208   GNRC                          Generac 2018-03-01 00:00:00+00:00
# 123    CZR            Caesars Entertainment 2020-03-18 00:00:00+00:00
# 21    ALGN                 Align Technology 2020-03-23 00:00:00+00:00
# 163   EPAM                     EPAM Systems 2018-02-09 00:00:00+00:00
# 411   SMCI                       Supermicro 2018-11-08 00:00:00+00:00
# 59    BIIB                           Biogen 2025-04-10 00:00:00+00:00
# 111    CRL       Charles River Laboratories 2018-02-08 00:00:00+00:00
# 330   NCLH   Norwegian Cruise Line Holdings 2020-03-18 00:00:00+00:00
# 81     CCL                         Carnival 2022-10-10 00:00:00+00:00
# 364    PCG                 PG&E Corporation 2019-10-28 00:00:00+00:00
# 242   INTC                            Intel 2025-04-08 00:00:00+00:00
# 133     DG                   Dollar General 2025-01-17 00:00:00+00:00
# 337    NKE                       Nike, Inc. 2025-04-08 00:00:00+00:00
# 425    SWK           Stanley Black & Decker 2025-04-08 00:00:00+00:00
# 53     BAX             Baxter International 2025-04-15 00:00:00+00:00
# 40    APTV                            Aptiv 2020-03-18 00:00:00+00:00
# 36     APA                  APA Corporation 2020-04-01 00:00:00+00:00
# 41     ARE  Alexandria Real Estate Equities 2025-05-06 00:00:00+00:00
# 310   MKTX                      MarketAxess 2018-10-01 00:00:00+00:00
# 212    GPN                  Global Payments 2025-04-21 00:00:00+00:00
# 308    MHK                Mohawk Industries 2020-03-20 00:00:00+00:00
# 426   SWKS               Skyworks Solutions 2025-04-08 00:00:00+00:00
# 434   TECH                       Bio-Techne 2018-01-02 00:00:00+00:00
# 354     ON                 ON Semiconductor 2020-03-18 00:00:00+00:00
# 438    TGT               Target Corporation 2018-12-21 00:00:00+00:00
# 216    HAL                      Halliburton 2020-03-18 00:00:00+00:00
# 272    KMX                           CarMax 2020-03-20 00:00:00+00:00
# 367    PFE                           Pfizer 2025-04-10 00:00:00+00:00
# 14     AES                  AES Corporation 2018-02-08 00:00:00+00:00
# 317    MOS             Mosaic Company (The) 2020-03-18 00:00:00+00:00
# 127    DAY                         Dayforce 2018-04-27 00:00:00+00:00
# 234    HUM                           Humana 2020-03-23 00:00:00+00:00
# 50      BA                           Boeing 2020-03-20 00:00:00+00:00
# 292     LW                      Lamb Weston 2020-03-18 00:00:00+00:00
# 57    BF-B                              NaN 2025-02-12 00:00:00+00:00
# 493    WST     West Pharmaceutical Services 2018-04-06 00:00:00+00:00
# 361   PAYC                           Paycom 2018-01-02 00:00:00+00:00
# 393   REGN        Regeneron Pharmaceuticals 2019-09-27 00:00:00+00:00
# 502   ZBRA               Zebra Technologies 2018-01-02 00:00:00+00:00
# 89    CHTR           Charter Communications 2024-04-26 00:00:00+00:00
# 148    DVN                     Devon Energy 2020-03-18 00:00:00+00:00
# 266    KHC                      Kraft Heinz 2020-03-12 00:00:00+00:00
# 404   RVTY                          Revvity 2020-03-16 00:00:00+00:00
# 464    UPS            United Parcel Service 2018-12-24 00:00:00+00:00
# 436    TER                         Teradyne 2018-12-24 00:00:00+00:00
#
#      5Yr_StkPr_Low       5Yr_StkPr_High_Date  5Yr_StkPr_High   Cur_StkPr  \
# 321      12.260000 2021-08-09 00:00:00+00:00      484.470001   25.700001
# 482       6.710000 2021-03-19 00:00:00+00:00       77.269997    9.230000
# 360       9.481192 2021-03-22 00:00:00+00:00       90.424393   11.950000
# 161       1.940000 2022-12-02 00:00:00+00:00      336.000000   47.939999
# 327      27.030001 2021-10-21 00:00:00+00:00      173.455887   28.400000
# 481       8.006781 2018-12-03 00:00:00+00:00       63.160084   11.400000
# 157      50.060001 2022-01-04 00:00:00+00:00      352.947144   65.360001
# 20       48.150463 2022-11-11 00:00:00+00:00      315.363007   61.570000
# 477       7.260000 2018-01-22 00:00:00+00:00       40.411266    8.960000
# 389      50.389999 2021-07-23 00:00:00+00:00      308.529999   72.309998
# 208      43.340000 2021-11-01 00:00:00+00:00      505.799988  127.209999
# 123       7.100000 2021-10-01 00:00:00+00:00      119.489998   30.080000
# 21      137.720001 2021-09-08 00:00:00+00:00      729.919983  189.000000
# 163     104.870003 2021-11-08 00:00:00+00:00      717.489990  186.600006
# 411       1.165000 2024-03-13 00:00:00+00:00      118.806999   33.520000
# 59      113.379997 2021-06-10 00:00:00+00:00      414.709991  124.400002
# 111      98.190002 2021-09-24 00:00:00+00:00      458.299988  143.080002
# 330       7.770000 2018-01-26 00:00:00+00:00       60.930000   19.150000
# 81        6.380000 2018-01-29 00:00:00+00:00       66.217567   22.129999
# 364       3.781185 2018-10-17 00:00:00+00:00       48.717583   17.219999
# 242      18.129999 2021-04-09 00:00:00+00:00       62.083336   22.180000
# 133      68.001190 2022-10-28 00:00:00+00:00      248.253372   89.489998
# 337      53.270000 2021-11-05 00:00:00+00:00      169.295319   62.580002
# 425      55.860001 2021-05-10 00:00:00+00:00      194.687988   72.529999
# 53       27.799999 2020-04-20 00:00:00+00:00       84.964371   31.879999
# 40       33.549999 2021-11-03 00:00:00+00:00      178.119995   66.930000
# 36        3.582176 2022-06-07 00:00:00+00:00       46.751541   17.709999
# 41       71.570000 2021-12-30 00:00:00+00:00      195.171188   74.230003
# 310     164.277145 2020-12-22 00:00:00+00:00      565.632812  218.089996
# 212      67.470001 2021-04-29 00:00:00+00:00      212.030075   83.139999
# 308      58.660000 2018-01-31 00:00:00+00:00      281.059998  110.940002
# 426      49.200001 2021-04-26 00:00:00+00:00      181.414078   73.040001
# 434      31.705149 2021-09-24 00:00:00+00:00      132.838882   53.900002
# 354       8.450000 2023-08-01 00:00:00+00:00      108.089996   44.619999
# 438      52.325474 2021-11-16 00:00:00+00:00      243.338989  101.080002
# 216       4.268197 2018-01-23 00:00:00+00:00       49.506557   21.250000
# 272      44.270000 2021-11-09 00:00:00+00:00      154.850006   69.059998
# 367      21.185833 2021-12-16 00:00:00+00:00       51.624905   23.090000
# 14        7.808047 2022-12-13 00:00:00+00:00       26.326044   11.870000
# 317       6.395125 2022-04-18 00:00:00+00:00       72.681000   32.950001
# 127      30.520000 2021-11-02 00:00:00+00:00      130.320007   59.599998
# 234     205.592407 2022-11-03 00:00:00+00:00      549.854675  252.860001
# 50       95.010002 2019-03-01 00:00:00+00:00      430.299988  198.529999
# 292      41.508087 2023-07-03 00:00:00+00:00      110.870804   51.240002
# 57       30.455545 2020-11-24 00:00:00+00:00       75.889244   35.279999
# 493      81.404259 2021-12-30 00:00:00+00:00      467.231934  219.460007
# 361      79.267754 2021-11-02 00:00:00+00:00      545.167786  258.380005
# 393     273.109039 2024-08-27 00:00:00+00:00     1200.217651  575.630005
# 502     103.709999 2021-12-10 00:00:00+00:00      614.549988  300.109985
# 89      254.610001 2021-09-02 00:00:00+00:00      821.010010  402.519989
# 148       4.054822 2022-10-31 00:00:00+00:00       68.412094   33.549999
# 266      16.044075 2018-01-23 00:00:00+00:00       57.306637   28.150000
# 404      65.912407 2021-12-31 00:00:00+00:00      199.442902   98.500000
# 464      72.039360 2022-02-02 00:00:00+00:00      203.230087  101.209999
# 436      28.097750 2021-12-27 00:00:00+00:00      166.226700   83.059998
#
#      Pct_Chg_f_High
# 321       -0.946952
# 482       -0.880549
# 360       -0.867845
# 161       -0.857321
# 327       -0.836270
# 481       -0.819506
# 157       -0.814816
# 20        -0.804765
# 477       -0.778280
# 389       -0.765631
# 208       -0.748497
# 123       -0.748263
# 21        -0.741068
# 163       -0.739927
# 411       -0.717862
# 59        -0.700031
# 111       -0.687803
# 330       -0.685705
# 81        -0.665799
# 364       -0.646534
# 242       -0.642738
# 133       -0.639522
# 337       -0.630350
# 425       -0.627455
# 53        -0.624784
# 40        -0.624242
# 36        -0.621189
# 41        -0.619667
# 310       -0.614432
# 212       -0.607886
# 308       -0.605280
# 426       -0.597385
# 434       -0.594245
# 354       -0.587196
# 438       -0.584612
# 216       -0.570764
# 272       -0.554020
# 367       -0.552735
# 14        -0.549116
# 317       -0.546649
# 127       -0.542664
# 234       -0.540133
# 50        -0.538624
# 292       -0.537840
# 57        -0.535112
# 493       -0.530298
# 361       -0.526054
# 393       -0.520395
# 502       -0.511659
# 89        -0.509726
# 148       -0.509590
# 266       -0.508783
# 404       -0.506124
# 464       -0.501993
# 436       -0.500321

# %%
df_min_max_cur['5Yr_StkPr_Low_Date'] = [datetime.strftime(date, '%Y-%m-%d') for date in df_min_max_cur['5Yr_StkPr_Low_Date']]
df_min_max_cur['5Yr_StkPr_High_Date'] = [datetime.strftime(date, '%Y-%m-%d') for date in df_min_max_cur['5Yr_StkPr_High_Date']]

# %%
df_min_max_cur.loc[(df_min_max_cur['Pct_Chg_f_High'] < threshold)].sort_values(by='5Yr_StkPr_Low_Date')
